# %%
import re
import pickle
import nltk
import seaborn as sns
import matplotlib.pyplot as plt
from def_text_summ import ROOT_DIR
from src.helpers.text_explorer import explore_text_and_summaries

# %% [markdown]
# As the dataset is already preprocessed there is a little need in extended exploration. Thus my goal is to make simple check of correspondence between texts and their summaries and distribution of words/sentences quantity for samples.
#
# This analysis will be made using custom function `explore_text_and_summaries`.

# %%
# train data
print('EXPLORING TRAIN DATA')
explore_text_and_summaries(text_path='/prep_data/train_data_prep',
                           summaries_path='/prep_data/train_labels_prep',
                           text_word_tok=True,
                           text_word_tok_path='/temp_data/train_tokenized_word_level')
# Out:
# EXPLORING TRAIN DATA
# ----------
# Basic parameters of texts and summaries:
# ----------
# Length of text is 287227
# ----------
# Comparison of text to its summary:
# ##########TEXT##########
# ...

# %%
# validation data
print('EXPLORING VALIDATION DATA')
explore_text_and_summaries(text_path='/prep_data/val_data_prep',
                           summaries_path='/prep_data/val_labels_prep')
# Out:
# EXPLORING VALIDATION DATA
# ----------
# Basic parameters of texts and summaries:
# ----------
# Length of text is 13368
# ----------
# Comparison of text to its summary:
# ##########TEXT##########
# ...

# %%
# test data
print('EXPLORING TEST DATA')
explore_text_and_summaries(text_path='/prep_data/test_data_prep',
                           summaries_path='/prep_data/test_labels_prep')
# Out:
# EXPLORING TEST DATA
# ----------
# Basic parameters of texts and summaries:
# ----------
# Length of text is 11490
# ----------
# Comparison of text to its summary:
# ##########TEXT##########
# ...

# %% [markdown]
# Exploration shows that all three sets have similar distribution of words/sentences quantity. Also summaries match initial text.
